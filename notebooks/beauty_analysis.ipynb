# %% [markdown]
# # Importing Libraries

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Importing and Analysing Dataset

# %%
# os.getcwd()
df = pd.read_csv("../datasets/beauty.csv")
df.head()
# Out:
#     wage  exper  union  goodhlth  black  female  married  service  educ  looks
# 0   5.73     30      0         1      0       1        1        1    14      4
# 1   4.28     28      0         1      0       1        1        0    12      3
# 2   7.96     35      0         1      0       1        0        0    10      4
# 3  11.57     38      0         1      0       0        1        1    16      3
# 4  11.42     27      0         1      0       0        1        0    16      3

# %%
df.shape
# Out:
# (1260, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1260 entries, 0 to 1259
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   wage      1260 non-null   float64
#  1   exper     1260 non-null   int64
#  2   union     1260 non-null   int64
#  3   goodhlth  1260 non-null   int64
#  4   black     1260 non-null   int64
#  5   female    1260 non-null   int64
#  6   married   1260 non-null   int64
#  7   service   1260 non-null   int64
#  8   educ      1260 non-null   int64
#  9   looks     1260 non-null   int64
# dtypes: float64(1), int64(9)
# memory usage: 98.6 KB

# %%
df.columns
# Out:
# Index(['wage', 'exper', 'union', 'goodhlth', 'black', 'female', 'married',
#        'service', 'educ', 'looks'],
#       dtype='object')

# %%
df['looks'].value_counts(normalize=True)
df['looks'].value_counts(normalize=False)
# Out:
# 3    722
# 4    364
# 2    142
# 5     19
# 1     13
# Name: looks, dtype: int64

# %%
df.hist(figsize=(10,12))
# Out:
# array([[<AxesSubplot: title={'center': 'wage'}>,
#         <AxesSubplot: title={'center': 'exper'}>,
#         <AxesSubplot: title={'center': 'union'}>],
#        [<AxesSubplot: title={'center': 'goodhlth'}>,
#         <AxesSubplot: title={'center': 'black'}>,
#         <AxesSubplot: title={'center': 'female'}>],
#        [<AxesSubplot: title={'center': 'married'}>,
#         <AxesSubplot: title={'center': 'service'}>,
#         <AxesSubplot: title={'center': 'educ'}>],
#        [<AxesSubplot: title={'center': 'looks'}>, <AxesSubplot: >,
#         <AxesSubplot: >]], dtype=object)

# %%
df['female'].value_counts(normalize=True)
# Out:
# 0    0.653968
# 1    0.346032
# Name: female, dtype: float64

# %%
df.describe()
# Out:
#               wage        exper        union     goodhlth        black  \
# count  1260.000000  1260.000000  1260.000000  1260.000000  1260.000000
# mean      6.306690    18.206349     0.272222     0.933333     0.073810
# std       4.660639    11.963485     0.445280     0.249543     0.261564
# min       1.020000     0.000000     0.000000     0.000000     0.000000
# 25%       3.707500     8.000000     0.000000     1.000000     0.000000
# 50%       5.300000    15.000000     0.000000     1.000000     0.000000
# 75%       7.695000    27.000000     1.000000     1.000000     0.000000
# max      77.720000    48.000000     1.000000     1.000000     1.000000
#
#             female      married      service         educ        looks
# count  1260.000000  1260.000000  1260.000000  1260.000000  1260.000000
# mean      0.346032     0.691270     0.273810    12.563492     3.185714
# std       0.475892     0.462153     0.446089     2.624489     0.684877
# ...

# %%
df[df['wage']>7.695000] #75 percent values less than 7.695000
# Out:
#        wage  exper  union  goodhlth  black  female  married  service  educ  \
# 2      7.96     35      0         1      0       1        0        0    10
# 3     11.57     38      0         1      0       0        1        1    16
# 4     11.42     27      0         1      0       0        1        0    16
# 6      8.76     12      0         1      0       0        1        0    16
# 14     7.99     12      0         1      0       0        1        0    16
# ...     ...    ...    ...       ...    ...     ...      ...      ...   ...
# 1235   8.75     24      1         1      0       0        0        1    16
# 1244  12.82     15      1         1      0       0        1        0    13
# 1248  10.58     19      0         1      0       0        0        0    16
# 1249   8.65     10      1         1      0       0        1        0    13
# 1252   9.62     21      1         1      0       0        1        0    16
#
#       looks
# 2         4
# 3         3
# 4         3
# 6         3
# ...

# %%
df[df['wage']>20].shape #24 values greater than 20 dollars per hour wage
# Out:
# (24, 10)

# %%
df['goodhlth'].value_counts(normalize=True)
# Out:
# 1    0.933333
# 0    0.066667
# Name: goodhlth, dtype: float64

# %%
df[(df['goodhlth']==1) & (df['wage']>df['wage'].mean())].shape
# Out:
# (464, 10)

# %%
first = df.sort_values(by=['wage','goodhlth','looks'],ascending=False)
first
# Out:
#        wage  exper  union  goodhlth  black  female  married  service  educ  \
# 602   77.72      9      1         1      1       1        1        1    13
# 269   41.67     16      0         0      0       0        1        0    13
# 415   38.86     29      0         1      0       0        1        0    13
# 69    32.79     33      0         1      0       0        1        1    16
# 290   31.09     32      0         0      0       0        1        0    13
# ...     ...    ...    ...       ...    ...     ...      ...      ...   ...
# 462    1.16      2      0         1      0       1        0        0    13
# 597    1.16      5      0         1      0       1        1        1    10
# 1226   1.09      8      0         1      0       1        1        1    10
# 1009   1.05     29      0         1      1       0        1        0     5
# 1214   1.02     11      0         1      0       1        1        1    13
#
#       looks
# 602       4
# 269       4
# 415       3
# 69        4
# ...

# %%
first[(first['married']==1) & first['female']==1]
# Out:
#        wage  exper  union  goodhlth  black  female  married  service  educ  \
# 602   77.72      9      1         1      1       1        1        1    13
# 149   10.62     18      1         1      0       1        1        1    17
# 334   10.53     18      0         1      0       1        1        1    16
# 166    9.75      8      1         1      0       1        1        1    16
# 50     9.16     19      1         1      0       1        1        1    17
# ...     ...    ...    ...       ...    ...     ...      ...      ...   ...
# 845    1.20      5      0         1      0       1        1        0    12
# 874    1.20      4      0         1      0       1        1        0    12
# 597    1.16      5      0         1      0       1        1        1    10
# 1226   1.09      8      0         1      0       1        1        1    10
# 1214   1.02     11      0         1      0       1        1        1    13
#
#       looks
# 602       4
# 149       3
# 334       3
# 166       3
# ...

# %%
# first.shape
first[(first['black']==0) & (first['looks']>first['looks'].mean())].shape[0]/first.shape[0] * 100

# 28 percent people are not black having looks value greater than mean looks value i.e 3
# around 2 percent people are black having looks value greater than mean looks value i.e 3
# Out:
# 28.174603174603174

# %%
first[(first['married']==1) & (first['female']==1)].describe() #Women married
# Out:
#              wage       exper       union    goodhlth       black  female  \
# count  213.000000  213.000000  213.000000  213.000000  213.000000   213.0
# mean     4.299859   14.417840    0.225352    0.910798    0.089202     1.0
# std      5.436832    9.573404    0.418798    0.285706    0.285706     0.0
# min      1.020000    0.000000    0.000000    0.000000    0.000000     1.0
# 25%      2.330000    7.000000    0.000000    1.000000    0.000000     1.0
# 50%      3.580000   12.000000    0.000000    1.000000    0.000000     1.0
# 75%      5.030000   19.000000    0.000000    1.000000    0.000000     1.0
# max     77.720000   47.000000    1.000000    1.000000    1.000000     1.0
#
#        married     service        educ       looks
# count    213.0  213.000000  213.000000  213.000000
# mean       1.0    0.427230   12.431925    3.131455
# std        0.0    0.495842    2.302852    0.681007
# min        1.0    0.000000    5.000000    1.000000
# ...

# %%
first[(first['married']==1) & (first['female']==0)].describe()  #Men married
# Out:
#              wage       exper       union    goodhlth       black  female  \
# count  658.000000  658.000000  658.000000  658.000000  658.000000   658.0
# mean     7.716778   22.136778    0.308511    0.937690    0.037994     0.0
# std      4.798763   11.714753    0.462230    0.241902    0.191327     0.0
# min      1.050000    1.000000    0.000000    0.000000    0.000000     0.0
# 25%      4.810000   12.000000    0.000000    1.000000    0.000000     0.0
# 50%      6.710000   20.500000    0.000000    1.000000    0.000000     0.0
# 75%      8.890000   32.000000    1.000000    1.000000    0.000000     0.0
# max     41.670000   48.000000    1.000000    1.000000    1.000000     0.0
#
#        married     service        educ       looks
# count    658.0  658.000000  658.000000  658.000000
# mean       1.0    0.194529   12.495441    3.164134
# std        0.0    0.396139    2.716007    0.655469
# min        1.0    0.000000    5.000000    1.000000
# ...

# %%
first[(first['married']==0) & (first['female']==1)].describe() #Women Non married
# Out:
#              wage       exper       union    goodhlth       black  female  \
# count  223.000000  223.000000  223.000000  223.000000  223.000000   223.0
# mean     4.298879   13.878924    0.197309    0.928251    0.139013     1.0
# std      2.160781   11.172225    0.398863    0.258652    0.346739     0.0
# min      1.160000    0.000000    0.000000    0.000000    0.000000     1.0
# 25%      2.570000    5.000000    0.000000    1.000000    0.000000     1.0
# 50%      3.890000   10.000000    0.000000    1.000000    0.000000     1.0
# 75%      5.395000   20.000000    0.000000    1.000000    0.000000     1.0
# max     12.120000   46.000000    1.000000    1.000000    1.000000     1.0
#
#        married     service        educ       looks
# count    223.0  223.000000  223.000000  223.000000
# mean       0.0    0.448430   12.753363    3.269058
# std        0.0    0.498452    2.747181    0.746935
# min        0.0    0.000000    5.000000    1.000000
# ...

# %%
first[(first['married']==0) & (first['female']==0)].describe() #Men not married
# Out:
#              wage       exper       union    goodhlth       black  female  \
# count  166.000000  166.000000  166.000000  166.000000  166.000000   166.0
# mean     5.989578   13.301205    0.289157    0.951807    0.108434     0.0
# std      3.333094   11.414754    0.454743    0.214821    0.311868     0.0
# min      1.170000    0.000000    0.000000    0.000000    0.000000     0.0
# 25%      3.750000    4.000000    0.000000    1.000000    0.000000     0.0
# 50%      5.065000    9.000000    0.000000    1.000000    0.000000     0.0
# 75%      7.690000   18.750000    1.000000    1.000000    0.000000     0.0
# max     23.160000   47.000000    1.000000    1.000000    1.000000     0.0
#
#        married     service        educ       looks
# count    166.0  166.000000  166.000000  166.000000
# mean       0.0    0.156627   12.746988    3.228916
# std        0.0    0.364548    2.468435    0.710532
# min        0.0    0.000000    5.000000    1.000000
# ...

# %%
plt.plot(df['wage'],df.index)

# %%
first[(first['union']==1)].describe() #I think that people in any professional union society does not advantage much (advantage a little)
# Out:
#              wage       exper  union    goodhlth       black      female  \
# count  343.000000  343.000000  343.0  343.000000  343.000000  343.000000
# mean     7.026764   19.962099    1.0    0.924198    0.087464    0.268222
# std      4.838225   12.084559    0.0    0.265067    0.282926    0.443681
# min      1.320000    0.000000    1.0    0.000000    0.000000    0.000000
# 25%      4.790000   10.000000    1.0    1.000000    0.000000    0.000000
# 50%      6.540000   18.000000    1.0    1.000000    0.000000    0.000000
# 75%      8.440000   30.000000    1.0    1.000000    0.000000    1.000000
# max     77.720000   46.000000    1.0    1.000000    1.000000    1.000000
#
#           married     service        educ       looks
# count  343.000000  343.000000  343.000000  343.000000
# mean     0.731778    0.198251   12.151603    3.137026
# std      0.443681    0.399264    2.778424    0.617862
# min      0.000000    0.000000    5.000000    1.000000
# ...

# %%
df.exper.hist()
# Out:
# <AxesSubplot: >

# %%
# df.exper.describe()
first.sort_values(by=['exper','wage'],ascending=False) #even higher experience people have low wages per hour in usd
# Out:
#       wage  exper  union  goodhlth  black  female  married  service  educ  \
# 595   8.46     48      0         1      0       0        1        0    13
# 323   6.41     48      0         1      0       0        1        0     8
# 1122  6.25     47      0         0      1       1        1        0     5
# 831   5.73     47      0         1      0       0        1        0    10
# 1094  3.82     47      0         1      0       0        0        0    12
# ...    ...    ...    ...       ...    ...     ...      ...      ...   ...
# 1138  1.17      1      0         1      1       0        0        0    12
# 620   2.88      0      0         1      0       1        0        1    12
# 878   2.63      0      1         1      0       1        1        0    10
# 959   2.40      0      1         0      0       0        0        0     8
# 811   1.27      0      0         1      0       1        0        0    10
#
#       looks
# 595       3
# 323       3
# 1122      4
# 831       3
# ...
